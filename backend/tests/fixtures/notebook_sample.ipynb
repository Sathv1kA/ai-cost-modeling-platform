# %% [markdown]
# # Test notebook
# Some prose about an LLM call.

# %%
from openai import OpenAI
client = OpenAI()

# %%
resp = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": "Summarize this paragraph."}],
    max_tokens=150,
)
